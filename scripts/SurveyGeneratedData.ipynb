# %%
import pandas as pd
from faker import Faker
import random

# Initialize Faker
fake = Faker()

# Define the number of records
num_records = 600

# Define possible values for some columns
last_names = [
    "Akinola", "Balogun", "Okoro", "Oluwole", "Adebayo", "Nwosu", "Obi", "Ibrahim", 
    "Ahmed", "Ogundele", "Oladipo", "Chukwu", "Anyanwu", "Olayinka", "Eze", 
    "Ogbonna", "Adeleke", "Ogunleye", "Okeke", "Olorunfemi", "Ebi", "Abubakar", 
    "Idris", "Onyeka", "Oduwole", "Mohammed", "Hassan", "Lawal", "Udo", "Ekanem", 
    "Bello", "Fashola", "Osakwe", "Danladi", "Nnamdi", "Femi", "Yusuf", "Ogidi", 
    "Yaro", "Oyedepo", "Alabi", "Ajayi", "Ajibola", "Oshodi", "Ogunsanya", "Baba",
    "Sanni", "Aloye", "Aduku", "Mmaduako", "Salam", "Adesakin", "Sheriff", "Yakubu", 
    "Igbe", "Zarami", "Adebayo", "Stephen", "Yusuf", "Usman", "Olorunfemi", "Ejugwu", 
    "Ishaya", "Okafor", "Jabbi", "Ejeh", "Omesili", "Jayeola", "Uyieidem", "Omora", 
    "Elkanah", "Elaigwu", "Kolapo", "Oluwasanmi", "Abdullahi", "Nwaogwugwu", "Sanbauna", 
    "Ibrahim", "Grace", "Saadu", "Etim", "Akinlade", "Egbunu", "Ene", "Oni", "Okon", 
    "Andrew", "Ladan", "Ogbozor", "Ochoja", "Aminu", "Edeh", "Nnamani", "Otu", 
    "Mohammed", "Adegunju", "Abraham", "Ezeji", "Augustine", "Nnenanya", "Ajeigbe", 
    "Ehanmo", "Eze", "Osanyintipin", "Tsadu", "Njoku", "Ibiam", "Mohammed", "Udofia", 
    "Olaleye", "Amus", "Ekpe", "Odoh", "Okwe", "Ogunbanjo", "Patrick", "Ibiam", "Ehanmo", 
    "Njoku", "Osanyintipin", "Yakubu", "Egbon", "Rasaki", "Abdulqadir", "Ogore", "Kelechi", 
    "James", "Osanyintipin", "Omoh", "Ibiam", "Obiora", "Onyeka", "Udo", "Musa", "Bashar", 
    "Ahmad", "Yusuf", "Afolayan", "Badamasi", "Arinze", "Nnaemeka", "Okorie", "Abdulaziz", 
    "Adeola", "Ahmad", "Sunday", "Nnanna", "Okolie", "Anaba", "Isong", "Igwe", "Akinbode", 
    "Ogunyemi", "Sogbetun", "Oyeniran", "Oguntayo", "Ayeni", "Ehanmo", "Odugu", "Odumodu", 
    "Anjorin", "Okeke", "Onyeka", "Asemota", "Nwadi", "Yekini", "Taiwo", "Uwa", "Igbo", 
    "Yahaya", "Sani", "Yusuf"
]

first_names = [
    "Adeola", "Chinedu", "Ifeanyi", "Oluwaseun", "Emeka", "Ngozi", "Temitope", 
    "Kehinde", "Yemi", "Nneka", "Adebayo", "Abiodun", "Chisom", "Ijeoma", 
    "Uche", "Gbenga", "Tunde", "Bola", "Chidi", "Bimbo", "Bisi", "Bassey", 
    "Ikechukwu", "Musa", "Aisha", "Rashidat", "Fatima", "Hassan", "Sadiq",
    "Bukola", "Adamu", "Umar", "Sani", "Ibrahim", "Samuel", "Sunday", "Blessing", 
    "Mercy", "Patience", "Omotola", "Tolu", "Chika", "Olamide", "Funke", "Damilola",
    "Lovina", "Ibrahim", "Chidiebere", "Isma'il", "Samuel", "Amiel", "Henry", 
    "Nanle", "Alhaji", "Augustina", "Christiana", "Khadijah", "Betty", "Felix", 
    "Jerome", "Umar", "Victoria", "Asukwo", "Tajudeen", "Johnson", "Charity", 
    "Longdi", "Sunday", "Jamilu", "Oladipupo", "Mary", "Nwanyinnaya", "Ebisu", 
    "Ude", "Olanrewaju", "Mathew", "Yohanna", "Kitoye", "Kenith", "Emmanuel", 
    "Monisola", "Nihinlola", "Silas", "Muhammad", "Adamu", "Umahi", "Mustapha", 
    "Ayodele", "Binam", "John-pius", "Dare", "Victor", "Sodiq", "Ufedo", "Gerald", 
    "Emmanuel", "Mohammed", "Philip", "Sunday", "Igbalumun", "Ayodeji", "Samuel", 
    "Funbi", "Chukwunonso", "Emeke", "Blessing", "Lateef", "Mathew", "Cyril", 
    "Isong", "Emmanuel", "Nduka", "Anzaku", "Abba", "Musa", "Maxwell", "Harisu", 
    "Johnson", "Femi", "Sadiq", "Peter", "Lilian", "Babatunde", "Waheed", "Agai", 
    "Godwin", "Emmanuel", "Hassan", "Clement", "Esther", "Mhungur", "Oleje", 
    "Kabiru", "Bridget", "Isiaka", "Nnedinma", "Ndubuisi", "Emmanuel", "Ternenge", 
    "Joseph", "Inimfon", "Joy", "Felicia", "Zaharudeen", "Omotomilola", "Gbuuka", 
    "Rasaki", "Ifeoma", "Abdullahi", "Hassanat", "Franklin", "Kelechi", "Sani", 
    "Ruth", "Temitayo", "Edward", "Ngozi", "Zayyanu", "Adekunle", "Jafar", "Olatunde", 
    "Isah", "Blessing", "Paul", "Oliver", "Oluwaseun", "Amadi", "Naomi", "Joseph", 
    "Adewumi", "Fatai", "Ugonma", "Mansir", "Haladu", "Terhemba", "Isiyaka", "Sunday", 
    "Binny", "Daniel", "Amomot", "John", "Chinonso", "Vivian", "Fidelis", "Uchechukwu", 
    "Matthew", "Saidu", "Bashar", "Collins", "Nneka", "Roseline", "Alice", "Felicia", 
    "Ibrahim", "Nnamdi", "Zahra", "Kingsley", "Mustapha", "Charity", "Funke", "Atim", 
    "Philip", "Zainab"
]
genders = ["Male", "Female"]
school_types = ["Public", "Private"]
lga_options = [
    "Agege", "Alimosho", "Apapa", "Ifako-Ijaye", "Ikeja", "Kosofe", "Mushin", "Oshodi-Isolo", 
    "Shomolu", "Eti-Osa", "Lagos Island", "Lagos Mainland", "Surulere", "Ojo", 
    "Ajeromi-Ifelodun", "Amuwo-Odofin", "Badagry", "Ikorodu", "Ibeju-Lekki", "Epe"
]
ambitions = ["Engineer", "Doctor", "Teacher", "Developer", "Artist", "Scientist", "Businessperson", "Lawyer"]
occupations = ["Farmer", "Teacher", "Engineer", "Doctor", "Banker", "Scientist", "Entrepreneur"]
states = [
    "Abia", "Adamawa", "Akwa Ibom", "Anambra", "Bauchi", "Bayelsa", "Benue", "Borno", 
    "Cross River", "Delta", "Ebonyi", "Edo", "Ekiti", "Enugu", "Gombe", "Imo", 
    "Jigawa", "Kaduna", "Kano", "Kogi", "Kwara", "Lagos", "Nasarawa", "Niger", 
    "Ogun", "Ondo", "Osun", "Oyo", "Plateau", "Rivers", "Sokoto", "Taraba", 
    "Yobe", "Zamfara"
]

# Generate synthetic data
data = {
    "Student ID": [fake.unique.random_int(min=10000, max=99999) for _ in range(num_records)],
    "First Name": [random.choice(first_names) for _ in range(num_records)],
    "Last Name": [random.choice(last_names) for _ in range(num_records)],
    "Gender": [random.choice(genders) for _ in range(num_records)],
    "Date of Birth": [fake.date_of_birth(minimum_age=10, maximum_age=18) for _ in range(num_records)],
    "State of Origin": [random.choice(states) for _ in range(num_records)],
    "LGA": [random.choice(lga_options) for _ in range(num_records)],
    "School Type": [random.choice(school_types) for _ in range(num_records)],
    "Academic Ambition": [random.choice(ambitions) for _ in range(num_records)],
    "Parent Occupation": [random.choice(occupations) for _ in range(num_records)],
    "Phone Number": [fake.phone_number() for _ in range(num_records)],
    "Email": [fake.unique.email() for _ in range(num_records)],
}

# Create DataFrame
student_df = pd.DataFrame(data)

# Save DataFrame to CSV
# student_df.to_csv("synthetic_student_data.csv", index=False)

print("Synthetic student data generated and saved to 'synthetic_student_data.csv'")

# %%
import pandas as pd
from faker import Faker
import random

random.seed(42)


# Initialize Faker
fake = Faker()

# Define the number of records
num_records = 1000

# Define possible values for some columns
last_names = [
    "Akinola", "Balogun", "Okoro", "Oluwole", "Adebayo", "Nwosu", "Obi", "Ibrahim", 
    "Ahmed", "Ogundele", "Oladipo", "Chukwu", "Anyanwu", "Olayinka", "Eze", 
    "Ogbonna", "Adeleke", "Ogunleye", "Okeke", "Olorunfemi", "Ebi", "Abubakar",
     "Idris", "Onyeka", "Oduwole", "Mohammed", "Hassan", "Lawal", "Udo", "Ekanem", 
    "Bello", "Fashola", "Osakwe", "Danladi", "Nnamdi", "Femi", "Yusuf", "Ogidi", 
    "Yaro", "Oyedepo", "Alabi", "Ajayi", "Ajibola", "Oshodi", "Ogunsanya", "Baba",
    "Sanni", "Aloye", "Aduku", "Mmaduako", "Salam", "Adesakin", "Sheriff", "Yakubu", 
    "Igbe", "Zarami", "Adebayo", "Stephen", "Yusuf", "Usman", "Olorunfemi", "Ejugwu", 
    "Ishaya", "Okafor", "Jabbi", "Ejeh", "Omesili", "Jayeola", "Uyieidem", "Omora", 
    "Elkanah", "Elaigwu", "Kolapo", "Oluwasanmi", "Abdullahi", "Nwaogwugwu", "Sanbauna", 
    "Ibrahim", "Grace", "Saadu", "Etim", "Akinlade", "Egbunu", "Ene", "Oni", "Okon", 
    "Andrew", "Ladan", "Ogbozor", "Ochoja", "Aminu", "Edeh", "Nnamani", "Otu", 
    "Mohammed", "Adegunju", "Abraham", "Ezeji", "Augustine", "Nnenanya", "Ajeigbe", 
    "Ehanmo", "Eze", "Osanyintipin", "Tsadu", "Njoku", "Ibiam", "Mohammed", "Udofia", 
    "Olaleye", "Amus", "Ekpe", "Odoh", "Okwe", "Ogunbanjo", "Patrick", "Ibiam", "Ehanmo", 
    "Njoku", "Osanyintipin", "Yakubu", "Egbon", "Rasaki", "Abdulqadir", "Ogore", "Kelechi", 
    "James", "Osanyintipin", "Omoh", "Ibiam", "Obiora", "Onyeka", "Udo", "Musa", "Bashar", 
    "Ahmad", "Yusuf", "Afolayan", "Badamasi", "Arinze", "Nnaemeka", "Okorie", "Abdulaziz", 
    "Adeola", "Ahmad", "Sunday", "Nnanna", "Okolie", "Anaba", "Isong", "Igwe", "Akinbode", 
    "Ogunyemi", "Sogbetun", "Oyeniran", "Oguntayo", "Ayeni", "Ehanmo", "Odugu", "Odumodu", 
    "Anjorin", "Okeke", "Onyeka", "Asemota", "Nwadi", "Yekini", "Taiwo", "Uwa", "Igbo", 
    "Yahaya", "Sani", "Yusuf"
]

first_names = [
    "Adeola", "Chinedu", "Ifeanyi", "Oluwaseun", "Emeka", "Ngozi", "Temitope", 
    "Kehinde", "Yemi", "Nneka", "Adebayo", "Abiodun", "Chisom", "Ijeoma", 
    "Uche", "Gbenga", "Tunde", "Bola", "Chidi", "Bimbo", "Bisi", "Bassey", 
    "Ikechukwu", "Musa", "Aisha", "Rashidat", "Fatima", "Hassan", "Sadiq",
    "Bukola", "Adamu", "Umar", "Sani", "Ibrahim", "Samuel", "Sunday", "Blessing", 
    "Mercy", "Patience", "Omotola", "Tolu", "Chika", "Olamide", "Funke", "Damilola",
        "Lovina", "Ibrahim", "Chidiebere", "Isma'il", "Samuel", "Amiel", "Henry", 
    "Nanle", "Alhaji", "Augustina", "Christiana", "Khadijah", "Betty", "Felix", 
    "Jerome", "Umar", "Victoria", "Asukwo", "Tajudeen", "Johnson", "Charity", 
    "Longdi", "Sunday", "Jamilu", "Oladipupo", "Mary", "Nwanyinnaya", "Ebisu", 
    "Ude", "Olanrewaju", "Mathew", "Yohanna", "Kitoye", "Kenith", "Emmanuel", 
    "Monisola", "Nihinlola", "Silas", "Muhammad", "Adamu", "Umahi", "Mustapha", 
    "Ayodele", "Binam", "John-pius", "Dare", "Victor", "Sodiq", "Ufedo", "Gerald", 
    "Emmanuel", "Mohammed", "Philip", "Sunday", "Igbalumun", "Ayodeji", "Samuel", 
    "Funbi", "Chukwunonso", "Emeke", "Blessing", "Lateef", "Mathew", "Cyril", 
    "Isong", "Emmanuel", "Nduka", "Anzaku", "Abba", "Musa", "Maxwell", "Harisu", 
    "Johnson", "Femi", "Sadiq", "Peter", "Lilian", "Babatunde", "Waheed", "Agai", 
    "Godwin", "Emmanuel", "Hassan", "Clement", "Esther", "Mhungur", "Oleje", 
    "Kabiru", "Bridget", "Isiaka", "Nnedinma", "Ndubuisi", "Emmanuel", "Ternenge", 
    "Joseph", "Inimfon", "Joy", "Felicia", "Zaharudeen", "Omotomilola", "Gbuuka", 
    "Rasaki", "Ifeoma", "Abdullahi", "Hassanat", "Franklin", "Kelechi", "Sani", 
    "Ruth", "Temitayo", "Edward", "Ngozi", "Zayyanu", "Adekunle", "Jafar", "Olatunde", 
    "Isah", "Blessing", "Paul", "Oliver", "Oluwaseun", "Amadi", "Naomi", "Joseph", 
    "Adewumi", "Fatai", "Ugonma", "Mansir", "Haladu", "Terhemba", "Isiyaka", "Sunday", 
    "Binny", "Daniel", "Amomot", "John", "Chinonso", "Vivian", "Fidelis", "Uchechukwu", 
    "Matthew", "Saidu", "Bashar", "Collins", "Nneka", "Roseline", "Alice", "Felicia", 
    "Ibrahim", "Nnamdi", "Zahra", "Kingsley", "Mustapha", "Charity", "Funke", "Atim", 
    "Philip", "Zainab"
]
genders = ["Male", "Female"]
school_types = ["Public", "Private"]
lga_options = [
    "Agege", "Alimosho", "Apapa", "Ifako-Ijaye", "Ikeja", "Kosofe", "Mushin", "Oshodi-Isolo", 
    "Shomolu", "Eti-Osa", "Lagos Island", "Lagos Mainland", "Surulere", "Ojo", 
    "Ajeromi-Ifelodun", "Amuwo-Odofin", "Badagry", "Ikorodu", "Ibeju-Lekki", "Epe"
]
ambitions = ["Engineer", "Doctor", "Teacher", "Developer", "Artist", "Scientist", "Businessperson", "Lawyer"]
occupations = ["Farmer", "Teacher", "Engineer", "Medical Professional", "Business", "Civil Servant"]
study_habits = ["Daily", "Occasional", "Rarely"]
behavior_conditions = ["Minor Issues", "Major Issues", "Good", "Excellent", "Average"]

# Generate synthetic data
data = {
    "Last Name": [random.choice(last_names) for _ in range(num_records)],
    "First Name": [random.choice(first_names) for _ in range(num_records)],
    "Date of Birth": [fake.date_of_birth(minimum_age=13, maximum_age=19) for _ in range(num_records)],
    "Gender": [random.choice(genders) for _ in range(num_records)],
    "Address LGA": [random.choice(lga_options) for _ in range(num_records)],
    "State of Origin": [fake.state() for _ in range(num_records)],
    "Geopolitical Zone": [random.choice(["North East", "North West", "South East", "South West", "South South"]) for _ in range(num_records)],
    "School Type": [random.choice(school_types) for _ in range(num_records)],
    "Schools LGA": [random.choice(lga_options) for _ in range(num_records)],
    "Secondary School Living Arrangement": [random.choice(["Day", "Boarding"]) for _ in range(num_records)],
    "Digital methods in school": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Weekly Hours Spent Reading": [random.choice(["1 hour", "3 hours", "5 hours", "10 hours", "32 hours"]) for _ in range(num_records)],
    "Mentor": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Parents Occupation": [random.choice(occupations) for _ in range(num_records)],
    "Financial status": [random.choice(["Low Income", "Middle Income", "High Income"]) for _ in range(num_records)],
    "Future Ambition": [random.choice(ambitions) for _ in range(num_records)],
    "Digital literacy": [random.choice(["Low", "Medium", "High"]) for _ in range(num_records)],
    "Extra Extracurricular Activities": [random.choice(["Clubs", "Sports", "Music", "Drama", "None"]) for _ in range(num_records)],
    "Do you have a library in your school?": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Library visit": [random.choice(["Often", "Sometimes", "Rarely"]) for _ in range(num_records)],
    "Academic Stream": [random.choice(["Science", "Arts", "Commerce"]) for _ in range(num_records)],
    "Attendance Rate": [random.randint(1, 10) for _ in range(num_records)],  # Random attendance rate from 1 to 10
    "Study Habits": [random.choice(study_habits) for _ in range(num_records)],
    "Behavioral Condition in School": [random.choice(behavior_conditions) for _ in range(num_records)],
    "Learning Environment": [random.choice(["Good", "Average", "Poor"]) for _ in range(num_records)],
    "Private Tutors": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Access to online Learning Platform": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Supportive Home Environment": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Parental Engagement in School Life": [random.choice(["Strongly Agree", "Agree", "Neutral", "Disagree", "Strongly Disagree"]) for _ in range(num_records)],
    "Qualified Teachers": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Anxiety Before Exam": [random.choice(["High", "Medium", "Low"]) for _ in range(num_records)],
    "Do you understand English": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Access to Practice Exams": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Past Jamb Score": [random.randint(100, 340) for _ in range(num_records)],
    "Credit pass in core five subjects": [random.choice(["Yes", "No"]) for _ in range(num_records)],
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV (optional)
df.to_csv("survey_student_data.csv", index=False)

# Display the first few rows of the DataFrame
df.head()
# Out:
#   Last Name First Name Date of Birth  Gender Address LGA State of Origin  \
# 0   Asemota      Silas    2010-03-15    Male    Surulere            Iowa
# 1       Udo     Ugonma    2008-09-22  Female      Kosofe        Michigan
# 2       Obi     Fatima    2011-04-19    Male      Kosofe           Maine
# 3   Elkanah      Chika    2008-10-18    Male         Ojo      Washington
# 4    Ishaya      Adamu    2005-12-18  Female    Surulere         Vermont
#
#   Geopolitical Zone School Type   Schools LGA  \
# 0        North West      Public        Kosofe
# 1        South East      Public           Epe
# 2        South East     Private  Oshodi-Isolo
# 3        South West      Public       Eti-Osa
# 4       South South      Public        Mushin
#
#   Secondary School Living Arrangement  ... Private Tutors  \
# 0                            Boarding  ...             No
# 1                                 Day  ...            Yes
# 2                                 Day  ...             No
# ...

# %%
import pandas as pd
from faker import Faker
import random

# Initialize Faker
fake = Faker()

# Define the number of records
num_records = 600

# Define possible values for some columns
last_names = [
    "Akinola", "Balogun", "Okoro", "Oluwole", "Adebayo", "Nwosu", "Obi", "Ibrahim", 
    "Ahmed", "Ogundele", "Oladipo", "Chukwu", "Anyanwu", "Olayinka", "Eze", 
    "Ogbonna", "Adeleke", "Ogunleye", "Okeke", "Olorunfemi", "Ebi", "Abubakar", 
   
]

first_names = [
    "Adeola", "Chinedu", "Ifeanyi", "Oluwaseun", "Emeka", "Ngozi", "Temitope", 
    "Kehinde", "Yemi", "Nneka", "Adebayo", "Abiodun", "Chisom", "Ijeoma", 
    "Uche", "Gbenga", "Tunde", "Bola", "Chidi", "Bimbo", "Bisi", "Bassey", 
    "Ikechukwu", "Musa", "Aisha", "Rashidat", "Fatima", "Hassan", "Sadiq",
    "Bukola", "Adamu", "Umar", "Sani", "Ibrahim", "Samuel", "Sunday", "Blessing", 
    "Mercy", "Patience", "Omotola", "Tolu", "Chika", "Olamide", "Funke", "Damilola",
  
]
genders = ["Male", "Female"]
school_types = ["Public", "Private"]
lga_options = [
    "Agege", "Alimosho", "Apapa", "Ifako-Ijaye", "Ikeja", "Kosofe", "Mushin", "Oshodi-Isolo", 
    "Shomolu", "Eti-Osa", "Lagos Island", "Lagos Mainland", "Surulere", "Ojo", 
    "Ajeromi-Ifelodun", "Amuwo-Odofin", "Badagry", "Ikorodu", "Ibeju-Lekki", "Epe"
]
ambitions = ["Engineer", "Doctor", "Teacher", "Developer", "Artist", "Scientist", "Businessperson", "Lawyer"]
occupations = ["Farmer", "Teacher", "Engineer", "Medical Professional", "Business", "Civil Servant"]
study_habits = ["Daily", "Occasional", "Rarely"]
behavior_conditions = ["Minor Issues", "Major Issues", "Good", "Excellent", "Average"]
attendance_rates = random.sample(range(1, 11), num_records)  # Random attendance rate from 1 to 10

# Generate synthetic data
data = {
    "Last Name": [random.choice(last_names) for _ in range(num_records)],
    "First Name": [random.choice(first_names) for _ in range(num_records)],
    "Date of Birth": [fake.date_of_birth(minimum_age=13, maximum_age=19) for _ in range(num_records)],
    "Gender": [random.choice(genders) for _ in range(num_records)],
    "Address LGA": [random.choice(lga_options) for _ in range(num_records)],
    "State of Origin": [fake.state() for _ in range(num_records)],
    "Geopolitical Zone": [random.choice(["North East", "North West", "South East", "South West", "South South"]) for _ in range(num_records)],
    "School Type": [random.choice(school_types) for _ in range(num_records)],
    "Schools LGA": [random.choice(lga_options) for _ in range(num_records)],
    "Secondary School Living Arrangement": [random.choice(["Day", "Boarding"]) for _ in range(num_records)],
    "Digital methods in school": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Weekly Hours Spent Reading": [random.choice(["1 hour", "3 hours", "5 hours", "10 hours", "32 hours"]) for _ in range(num_records)],
    "Mentor": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Parents Occupation": [random.choice(occupations) for _ in range(num_records)],
    "Financial status": [random.choice(["Low Income", "Middle Income", "High Income"]) for _ in range(num_records)],
    "Future Ambition": [random.choice(ambitions) for _ in range(num_records)],
    "Digital literacy": [random.choice(["Low", "Medium", "High"]) for _ in range(num_records)],
    "Extra Extracurricular Activities": [random.choice(["Clubs", "Sports", "Music", "Drama", "None"]) for _ in range(num_records)],
    "Do you have a library in your school?": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Library visit": [random.choice(["Often", "Sometimes", "Rarely"]) for _ in range(num_records)],
    "Academic Stream": [random.choice(["Science", "Arts", "Commerce"]) for _ in range(num_records)],
    "Attendance Rate": attendance_rates,
    "Study Habits": [random.choice(study_habits) for _ in range(num_records)],
    "Behavioral Condition in School": [random.choice(behavior_conditions) for _ in range(num_records)],
    "Learning Environment": [random.choice(["Good", "Average", "Poor"]) for _ in range(num_records)],
    "Private Tutors": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Access to online Learning Platform": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Supportive Home Environment": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Parental Engagement in School Life": [random.choice(["Strongly Agree", "Agree", "Neutral", "Disagree", "Strongly Disagree"]) for _ in range(num_records)],
    "Qualified Teachers": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Anxiety Before Exam": [random.choice(["High", "Medium", "Low"]) for _ in range(num_records)],
    "Do you understand English": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Access to Practice Exams": [random.choice(["Yes", "No"]) for _ in range(num_records)],
    "Past Jamb Score": [random.randint(100, 400) for _ in range(num_records)],
    "Credit pass in core five subjects": [random.choice(["Yes", "No"]) for _ in range(num_records)],
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV (optional)
# df.to_csv("synthetic_student_data.csv", index=False)

# Display the first few rows of the DataFrame
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 79
#      77 study_habits = ["Daily", "Occasional", "Rarely"]
#      78 behavior_conditions = ["Minor Issues", "Major Issues", "Good", "Excellent", "Average"]
# ---> 79 attendance_rates = random.sample(range(1, 11), num_records)  # Random attendance rate from 1 to 10
#      81 # Generate synthetic data
#      82 data = {
#      83     "Last Name": [random.choice(last_names) for _ in range(num_records)],
#      84     "First Name": [random.choice(first_names) for _ in range(num_records)],
#    (...)
#     117     "Credit pass in core five subjects": [random.choice(["Yes", "No"]) for _ in range(num_records)],
#     118 }
#
# File c:\Users\JOHNKENNEDY\Desktop\sample_project\env\lib\random.py:363, in Random.sample(self, population, k)
#     361 n = len(population)
#     362 if not 0 <= k <= n:
# ...
